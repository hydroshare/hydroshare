# %%
# !pip install hsclient
targets = ["beta.hydroshare.org", "www.hydroshare.org"]
clients = {}
filename = "local-build-discover.sh"
diffs= {}

# %%
from hsclient import HydroShare
for target in targets:
    hs = HydroShare(host=target, port=443, protocol='https')
    hs.sign_in()
    hs.resources = []
    diffs[target] = []
    clients[target] = hs

# %%
from time import time
from functools import wraps
import numpy as np
import scipy
  
def timer_func(func): 
    @wraps(func)
    def wrap_func(*args, **kwargs): 
        t1 = time() 
        result = func(*args, **kwargs)
        t2 = time()
        target = kwargs['target']
        diff = t2-t1
        diffs[target].append(diff)
        print(f'Function {func.__name__!r} executed in {(diff):.4f}s') 
        return result 
    return wrap_func


def create_res(hs, time=True, target=None):

    @timer_func
    def create_res_time(hs=None, target=None):
        resource = hs.create()
        hs.resources.append(resource)
    
    if time:
        create_res_time(hs=hs, target=target)
    else:
        resource = hs.create()
        hs.resources.append(resource)

@timer_func
def delete_resources(hs=None, target=None):
    for res in hs.resources:
        res.delete()

@timer_func
def download_all_resources(hs=None, target=None):
    for res in hs.resources:
        try:
            res.download()
        except Exception as e:
            print(e)

def download_single_resource(hs=None, target=None):
    create_res(hs, False)
    res = hs.resources[-1]
    res.file_upload(filename)

    @timer_func
    def download_single_resource_inner(hs=res, target=None):
        res.download()

    download_single_resource_inner(hs=res, target=target)

def delete_single_resource(hs=None, target=None):
    create_res(hs, False)
    res = hs.resources[-1]
    res.file_upload(filename)

    @timer_func
    def delete_single_resource_inner(hs=res, target=None):
        res.delete()

    delete_single_resource_inner(hs=res, target=target)

def upload_file(hs, target=None):
    create_res(hs, False)
    res = hs.resources[-1]

    @timer_func
    def upload_file_inner(hs=res, target=None):
        res.file_upload(filename)

    upload_file_inner(hs=res, target=target)


def create_dir_upload_file(hs=None, target=None):
    create_res(hs, False)
    res = hs.resources[-1]

    @timer_func
    def create_dir_upload_file_inner(hs=res, target=None):
        res.folder_create('New_Folder')
        res.file_upload(filename, destination_path='New_Folder')
    create_dir_upload_file_inner(hs=res, target=target)

def upload_and_movefile(hs=None, target=None):
    create_res(hs, False)
    res = hs.resources[-1]
    
    @timer_func
    def upload_and_movefile_inner(hs=res, target=None):
        res.folder_create('New_Folder')
        res.file_upload(filename, destination_path='New_Folder')
        file = res.file(path=f"New_Folder/{filename}]")
        res.file_rename(file, filename)
    upload_and_movefile_inner(hs=res, target=target)

def download_single_file(hs=None, target=None):
    create_res(hs, False)
    res = hs.resources[-1]
    res.file_upload(filename)

    @timer_func
    def download_single_file_inner(hs=res, target=target):
        file = res.file(path=filename)
        res.file_download(file)
    download_single_file_inner(hs=res, target=target)

def delete_single_file(hs=None, target=None):
    create_res(hs, False)
    res = hs.resources[-1]
    res.file_upload(filename)

    @timer_func
    def delete_single_file_inner(hs=res, target=None):
        file = res.file(path=filename)
        res.file_delete(file)
    delete_single_file_inner(hs=res, target=target)
        

def run_comparisons(functions_to_run, runs=1):
    for funct in functions_to_run:
        print(f"********* Start {funct.__name__!r} *********")
        for i in range(runs):
            for target in targets:
                client = clients[target]
                print(f"Starting run {i} of {funct.__name__} on {target}...")
                funct(hs=client, target=target)
                print(diffs[target])
        for target in targets:
            client = clients[target]
            print(f"Average time {funct.__name__!r} on {target}: {sum(diffs[target])/len(diffs[target])}")
            print(f"Devation for {funct.__name__!r} on {target}: {np.std(diffs[target])}")
        # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html
        result = scipy.stats.ttest_ind(diffs[targets[0]], diffs[targets[1]])
        print(result)
        print("\n\n")
        for target in targets:
            diffs[target].clear()

def clear_resources():
    for target in targets:
        client = clients[target]
        client.resources = []
        diffs[target].clear()

# %%
clear_resources()
run_comparisons([download_single_resource, upload_file, create_dir_upload_file, create_res ], runs=3)
run_comparisons([download_all_resources, delete_resources], runs=1)
# Out:
# ********* Start 'download_single_resource' *********
# Starting run 0 of download_single_resource on beta.hydroshare.org...
# Function 'download_single_resource_inner' executed in 37.9298s
# [37.92979097366333]
# Starting run 0 of download_single_resource on www.hydroshare.org...
# Function 'download_single_resource_inner' executed in 19.7112s
# [19.7112238407135]
# Starting run 1 of download_single_resource on beta.hydroshare.org...
# Function 'download_single_resource_inner' executed in 34.1435s
# [37.92979097366333, 34.1435010433197]
# Starting run 1 of download_single_resource on www.hydroshare.org...
# Function 'download_single_resource_inner' executed in 19.8524s
# [19.7112238407135, 19.85241198539734]
# Starting run 2 of download_single_resource on beta.hydroshare.org...
# Function 'download_single_resource_inner' executed in 39.8796s
# [37.92979097366333, 34.1435010433197, 39.87956357002258]
# Starting run 2 of download_single_resource on www.hydroshare.org...
# Function 'download_single_resource_inner' executed in 20.0098s
# [19.7112238407135, 19.85241198539734, 20.00975489616394]
# Average time 'download_single_resource' on beta.hydroshare.org: 37.31761852900187
# Devation for 'download_single_resource' on beta.hydroshare.org: 2.381409898087454
# Average time 'download_single_resource' on www.hydroshare.org: 19.857796907424927
# Devation for 'download_single_resource' on www.hydroshare.org: 0.12193426044668698
# TtestResult(statistic=10.355047505650855, pvalue=0.0004909220012435164, df=4.0)
#
#
#
# ********* Start 'upload_file' *********
# Starting run 0 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 5.8336s
# [5.833629846572876]
# Starting run 0 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9056s
# [2.905566930770874]
# Starting run 1 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9649s
# [5.833629846572876, 2.9649150371551514]
# Starting run 1 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.7098s
# [2.905566930770874, 2.7097668647766113]
# Starting run 2 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 6.1584s
# [5.833629846572876, 2.9649150371551514, 6.158428192138672]
# Starting run 2 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8627s
# [2.905566930770874, 2.7097668647766113, 2.8626861572265625]
# Average time 'upload_file' on beta.hydroshare.org: 4.985657691955566
# Devation for 'upload_file' on beta.hydroshare.org: 1.435020127389146
# Average time 'upload_file' on www.hydroshare.org: 2.8260066509246826
# Devation for 'upload_file' on www.hydroshare.org: 0.08403751581982752
# TtestResult(statistic=2.1246977433493504, pvalue=0.10080750688998565, df=4.0)
#
#
#
# ********* Start 'create_dir_upload_file' *********
# Starting run 0 of create_dir_upload_file on beta.hydroshare.org...
# Function 'create_dir_upload_file_inner' executed in 19.2124s
# [19.212385177612305]
# Starting run 0 of create_dir_upload_file on www.hydroshare.org...
# Function 'create_dir_upload_file_inner' executed in 10.8551s
# [10.855077981948853]
# Starting run 1 of create_dir_upload_file on beta.hydroshare.org...
# Function 'create_dir_upload_file_inner' executed in 19.4563s
# [19.212385177612305, 19.45630383491516]
# Starting run 1 of create_dir_upload_file on www.hydroshare.org...
# Function 'create_dir_upload_file_inner' executed in 10.9508s
# [10.855077981948853, 10.950828075408936]
# Starting run 2 of create_dir_upload_file on beta.hydroshare.org...
# Function 'create_dir_upload_file_inner' executed in 20.0643s
# [19.212385177612305, 19.45630383491516, 20.06431007385254]
# Starting run 2 of create_dir_upload_file on www.hydroshare.org...
# Function 'create_dir_upload_file_inner' executed in 10.5128s
# [10.855077981948853, 10.950828075408936, 10.512760639190674]
# Average time 'create_dir_upload_file' on beta.hydroshare.org: 19.577666362126667
# Devation for 'create_dir_upload_file' on beta.hydroshare.org: 0.3582277250268386
# Average time 'create_dir_upload_file' on www.hydroshare.org: 10.772888898849487
# Devation for 'create_dir_upload_file' on www.hydroshare.org: 0.18804618883711519
# TtestResult(statistic=30.77686178623871, pvalue=6.6405406712344655e-06, df=4.0)
#
#
#
# ********* Start 'create_res' *********
# Starting run 0 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 24.6130s
# [24.613037109375]
# Starting run 0 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.1331s
# [14.133060932159424]
# Starting run 1 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 25.6004s
# [24.613037109375, 25.600391149520874]
# Starting run 1 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.6677s
# [14.133060932159424, 14.667651891708374]
# Starting run 2 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 20.1469s
# [24.613037109375, 25.600391149520874, 20.146852731704712]
# Starting run 2 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.8345s
# [14.133060932159424, 14.667651891708374, 14.834500789642334]
# Average time 'create_res' on beta.hydroshare.org: 23.453426996866863
# Devation for 'create_res' on beta.hydroshare.org: 2.372592397698146
# Average time 'create_res' on www.hydroshare.org: 14.545071204503378
# Devation for 'create_res' on www.hydroshare.org: 0.29919223148688007
# TtestResult(statistic=5.2682149853157805, pvalue=0.006219677964633684, df=4.0)
#
#
#
# ********* Start 'download_all_resources' *********
# Starting run 0 of download_all_resources on beta.hydroshare.org...
# Function 'download_all_resources' executed in 271.7043s
# [271.704302072525]
# Starting run 0 of download_all_resources on www.hydroshare.org...
# Function 'download_all_resources' executed in 159.8346s
# [159.83457469940186]
# Average time 'download_all_resources' on beta.hydroshare.org: 271.704302072525
# Devation for 'download_all_resources' on beta.hydroshare.org: 0.0
# Average time 'download_all_resources' on www.hydroshare.org: 159.83457469940186
# Devation for 'download_all_resources' on www.hydroshare.org: 0.0
# TtestResult(statistic=nan, pvalue=nan, df=0.0)
#
#
#
# ********* Start 'delete_resources' *********
# Starting run 0 of delete_resources on beta.hydroshare.org...
# Function 'delete_resources' executed in 207.4393s
# [207.4393332004547]
# Starting run 0 of delete_resources on www.hydroshare.org...
# Function 'delete_resources' executed in 98.6100s
# [98.61000967025757]
# Average time 'delete_resources' on beta.hydroshare.org: 207.4393332004547
# Devation for 'delete_resources' on beta.hydroshare.org: 0.0
# Average time 'delete_resources' on www.hydroshare.org: 98.61000967025757
# Devation for 'delete_resources' on www.hydroshare.org: 0.0
# TtestResult(statistic=nan, pvalue=nan, df=0.0)

# %%
# Let's see if we can bump N and get some significance...
clear_resources()
run_comparisons([upload_file], runs=10)
# Out:
# ********* Start 'upload_file' *********
# Starting run 0 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8627s
# [2.8627121448516846]
# Starting run 0 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9627s
# [2.9626917839050293]
# Starting run 1 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8628s
# [2.8627121448516846, 2.862791061401367]
# Starting run 1 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9640s
# [2.9626917839050293, 2.9640250205993652]
# Starting run 2 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8802s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154]
# Starting run 2 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9651s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502]
# Starting run 3 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 3.1411s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154, 3.1410770416259766]
# Starting run 3 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9631s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502, 2.963108777999878]
# Starting run 4 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 7.7771s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154, 3.1410770416259766, 7.7771382331848145]
# Starting run 4 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8672s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502, 2.963108777999878, 2.8671600818634033]
# Starting run 5 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 5.8722s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154, 3.1410770416259766, 7.7771382331848145, 5.872165203094482]
# Starting run 5 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8636s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502, 2.963108777999878, 2.8671600818634033, 2.8635852336883545]
# Starting run 6 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 7.7780s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154, 3.1410770416259766, 7.7771382331848145, 5.872165203094482, 7.777996778488159]
# Starting run 6 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9257s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502, 2.963108777999878, 2.8671600818634033, 2.8635852336883545, 2.9257302284240723]
# Starting run 7 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8380s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154, 3.1410770416259766, 7.7771382331848145, 5.872165203094482, 7.777996778488159, 2.8379669189453125]
# Starting run 7 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9508s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502, 2.963108777999878, 2.8671600818634033, 2.8635852336883545, 2.9257302284240723, 2.9508020877838135]
# Starting run 8 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 5.9340s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154, 3.1410770416259766, 7.7771382331848145, 5.872165203094482, 7.777996778488159, 2.8379669189453125, 5.933972120285034]
# Starting run 8 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8625s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502, 2.963108777999878, 2.8671600818634033, 2.8635852336883545, 2.9257302284240723, 2.9508020877838135, 2.86246395111084]
# Starting run 9 of upload_file on beta.hydroshare.org...
# Function 'upload_file_inner' executed in 2.8605s
# [2.8627121448516846, 2.862791061401367, 2.8802077770233154, 3.1410770416259766, 7.7771382331848145, 5.872165203094482, 7.777996778488159, 2.8379669189453125, 5.933972120285034, 2.8605399131774902]
# Starting run 9 of upload_file on www.hydroshare.org...
# Function 'upload_file_inner' executed in 2.9654s
# [2.9626917839050293, 2.9640250205993652, 2.965050220489502, 2.963108777999878, 2.8671600818634033, 2.8635852336883545, 2.9257302284240723, 2.9508020877838135, 2.86246395111084, 2.9653780460357666]
# Average time 'upload_file' on beta.hydroshare.org: 4.480656719207763
# Devation for 'upload_file' on beta.hydroshare.org: 2.0174740657777948
# Average time 'upload_file' on www.hydroshare.org: 2.9289995431900024
# Devation for 'upload_file' on www.hydroshare.org: 0.043777406390043426
# TtestResult(statistic=2.3067835632889615, pvalue=0.03316938562186724, df=18.0)
#
#
#
# ********* Start 'download_all_resources' *********
# Starting run 0 of download_all_resources on beta.hydroshare.org...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 # Let's see if we can bump N and get some significance...
# ----> 2 run_comparisons([upload_file, download_all_resources, create_res], runs=10)
#
# Cell In[44], line 117, in run_comparisons(functions_to_run, runs)
#     115         client = clients[target]
#     116         print(f"Starting run {i} of {funct.__name__} on {target}...")
# --> 117         funct(hs=client, target=target)
#     118         print(diffs[target])
#     119 for target in targets:
#
# Cell In[44], line 10, in timer_func.<locals>.wrap_func(*args, **kwargs)
#       7 @wraps(func)
#       8 def wrap_func(*args, **kwargs):
#       9     t1 = time()
# ---> 10     result = func(*args, **kwargs)
#      11     t2 = time()
#      12     target = kwargs['target']
#
# Cell In[44], line 41, in download_all_resources(hs, target)
#      38 @timer_func
#      39 def download_all_resources(hs=None, target=None):
#      40     for res in hs.resources:
# ---> 41         res.download()
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:898, in Resource.download(self, save_path)
#     892 def download(self, save_path: str = "") -> str:
#     893     """
#     894     Downloads a zipped bagit archive of the resource from HydroShare
#     895     param save_path: A local path to save the bag to, defaults to the current working directory
#     896     returns: The relative pathname of the download
#     897     """
# --> 898     return self._hs_session.retrieve_bag(self._hsapi_path, save_path=save_path)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:811, in Resource._hsapi_path(self)
#     809 @property
#     810 def _hsapi_path(self):
# --> 811     path = urlparse(self.metadata.identifier).path
#     812     return '/hsapi' + path
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:269, in Aggregation.metadata(self)
#     266 @property
#     267 def metadata(self) -> BaseMetadata:
#     268     """A metadata object for reading and updating metadata values"""
# --> 269     return self._metadata
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:153, in Aggregation._metadata(self)
#     150 @property
#     151 def _metadata(self):
#     152     if not self._retrieved_metadata:
# --> 153         self._retrieved_metadata = self._retrieve_and_parse(self.metadata_path)
#     154     return self._retrieved_metadata
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:274, in Aggregation.metadata_path(self)
#     271 @property
#     272 def metadata_path(self) -> str:
#     273     """The path to the metadata file"""
# --> 274     return urlparse(str(self._map.describes.is_documented_by)).path
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:147, in Aggregation._map(self)
#     144 @property
#     145 def _map(self):
#     146     if not self._retrieved_map:
# --> 147         self._retrieved_map = self._retrieve_and_parse(self._map_path)
#     148     return self._retrieved_map
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:231, in Aggregation._retrieve_and_parse(self, path)
#     230 def _retrieve_and_parse(self, path):
# --> 231     file_str = self._hs_session.retrieve_string(path)
#     232     instance = load_rdf(file_str)
#     233     return instance
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:1229, in HydroShareSession.retrieve_string(self, path)
#    1228 def retrieve_string(self, path):
# -> 1229     file = self.get(path, status_code=200, allow_redirects=True)
#    1230     return file.content.decode()
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:1291, in HydroShareSession.get(self, path, status_code, **kwargs)
#    1289 response = self._session.get(url, **kwargs)
#    1290 if response.status_code != status_code:
# -> 1291     raise Exception(
#    1292         "Failed GET {}, status_code {}, message {}".format(url, response.status_code, response.content)
#    1293     )
#    1294 return response
#
# Exception: Failed GET https://beta.hydroshare.org:443/resource/29d9e616898042dfb1bf4f64222534a5/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:29d9e616898042dfb1bf4f64222534a5"}'

# %%
clear_resources()
run_comparisons([create_res, download_all_resources], runs=5)
# Out:
# ********* Start 'create_res' *********
# Starting run 0 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 29.6942s
# [29.694232940673828]
# Starting run 0 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.5412s
# [14.541159868240356]
# Starting run 1 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 28.9799s
# [29.694232940673828, 28.97987699508667]
# Starting run 1 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.0283s
# [14.541159868240356, 14.028294801712036]
# Starting run 2 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 26.3164s
# [29.694232940673828, 28.97987699508667, 26.316428899765015]
# Starting run 2 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.4391s
# [14.541159868240356, 14.028294801712036, 14.439146041870117]
# Starting run 3 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 31.3342s
# [29.694232940673828, 28.97987699508667, 26.316428899765015, 31.334249019622803]
# Starting run 3 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.0709s
# [14.541159868240356, 14.028294801712036, 14.439146041870117, 14.070937156677246]
# Starting run 4 of create_res on beta.hydroshare.org...
# Function 'create_res_time' executed in 16.7943s
# [29.694232940673828, 28.97987699508667, 26.316428899765015, 31.334249019622803, 16.794277906417847]
# Starting run 4 of create_res on www.hydroshare.org...
# Function 'create_res_time' executed in 14.0887s
# [14.541159868240356, 14.028294801712036, 14.439146041870117, 14.070937156677246, 14.08867883682251]
# Average time 'create_res' on beta.hydroshare.org: 26.623813152313232
# Devation for 'create_res' on beta.hydroshare.org: 5.174571843100285
# Average time 'create_res' on www.hydroshare.org: 14.233643341064454
# Devation for 'create_res' on www.hydroshare.org: 0.21281626209802565
# TtestResult(statistic=4.78482268515372, pvalue=0.0013821100298234501, df=8.0)
#
#
#
# ********* Start 'download_all_resources' *********
# Starting run 0 of download_all_resources on beta.hydroshare.org...
# Function 'download_all_resources' executed in 90.1556s
# [90.15561103820801]
# Starting run 0 of download_all_resources on www.hydroshare.org...
# Function 'download_all_resources' executed in 53.6584s
# [53.65841507911682]
# Starting run 1 of download_all_resources on beta.hydroshare.org...
# Function 'download_all_resources' executed in 43.5502s
# [90.15561103820801, 43.55023717880249]
# Starting run 1 of download_all_resources on www.hydroshare.org...
# Function 'download_all_resources' executed in 14.1015s
# [53.65841507911682, 14.10149097442627]
# Starting run 2 of download_all_resources on beta.hydroshare.org...
# Function 'download_all_resources' executed in 39.1156s
# [90.15561103820801, 43.55023717880249, 39.11555767059326]
# Starting run 2 of download_all_resources on www.hydroshare.org...
# Function 'download_all_resources' executed in 13.8274s
# [53.65841507911682, 14.10149097442627, 13.827441930770874]
# Starting run 3 of download_all_resources on beta.hydroshare.org...
# Function 'download_all_resources' executed in 34.4048s
# [90.15561103820801, 43.55023717880249, 39.11555767059326, 34.4047532081604]
# Starting run 3 of download_all_resources on www.hydroshare.org...
# Function 'download_all_resources' executed in 13.4726s
# [53.65841507911682, 14.10149097442627, 13.827441930770874, 13.472637176513672]
# Starting run 4 of download_all_resources on beta.hydroshare.org...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 2
#       1 clear_resources()
# ----> 2 run_comparisons([create_res, download_all_resources], runs=5)
#
# Cell In[54], line 131, in run_comparisons(functions_to_run, runs)
#     129         client = clients[target]
#     130         print(f"Starting run {i} of {funct.__name__} on {target}...")
# --> 131         funct(hs=client, target=target)
#     132         print(diffs[target])
#     133 for target in targets:
#
# Cell In[54], line 10, in timer_func.<locals>.wrap_func(*args, **kwargs)
#       7 @wraps(func)
#       8 def wrap_func(*args, **kwargs):
#       9     t1 = time()
# ---> 10     result = func(*args, **kwargs)
#      11     t2 = time()
#      12     target = kwargs['target']
#
# Cell In[54], line 42, in download_all_resources(hs, target)
#      40 for res in hs.resources:
#      41     try:
# ---> 42         res.download()
#      43     except Exception as e:
#      44         print(e)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:898, in Resource.download(self, save_path)
#     892 def download(self, save_path: str = "") -> str:
#     893     """
#     894     Downloads a zipped bagit archive of the resource from HydroShare
#     895     param save_path: A local path to save the bag to, defaults to the current working directory
#     896     returns: The relative pathname of the download
#     897     """
# --> 898     return self._hs_session.retrieve_bag(self._hsapi_path, save_path=save_path)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:1242, in HydroShareSession.retrieve_bag(self, path, save_path)
#    1241 def retrieve_bag(self, path, save_path=""):
# -> 1242     file = self.get(path, status_code=200, allow_redirects=True)
#    1244     if file.headers['Content-Type'] != "application/zip":
#    1245         time.sleep(1)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:1289, in HydroShareSession.get(self, path, status_code, **kwargs)
#    1287 def get(self, path, status_code, **kwargs):
#    1288     url = encode_resource_url(self._build_url(path))
# -> 1289     response = self._session.get(url, **kwargs)
#    1290     if response.status_code != status_code:
#    1291         raise Exception(
#    1292             "Failed GET {}, status_code {}, message {}".format(url, response.status_code, response.content)
#    1293         )
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
clear_resources()
run_comparisons([delete_single_file], runs=3)
# Out:
# ********* Start 'delete_single_file' *********
# Starting run 0 of delete_single_file on beta.hydroshare.org...
# Function 'delete_single_file_inner' executed in 29.7061s
# [29.706119298934937]
# Starting run 0 of delete_single_file on www.hydroshare.org...
# Function 'delete_single_file_inner' executed in 15.5633s
# [15.56330394744873]
# Starting run 1 of delete_single_file on beta.hydroshare.org...
# Function 'delete_single_file_inner' executed in 23.9646s
# [29.706119298934937, 23.964612007141113]
# Starting run 1 of delete_single_file on www.hydroshare.org...
# Function 'delete_single_file_inner' executed in 15.2583s
# [15.56330394744873, 15.258327960968018]
# Starting run 2 of delete_single_file on beta.hydroshare.org...
# Function 'delete_single_file_inner' executed in 24.8875s
# [29.706119298934937, 23.964612007141113, 24.887469053268433]
# Starting run 2 of delete_single_file on www.hydroshare.org...
# Function 'delete_single_file_inner' executed in 15.4993s
# [15.56330394744873, 15.258327960968018, 15.499326944351196]
# Average time 'delete_single_file' on beta.hydroshare.org: 26.186066786448162
# Devation for 'delete_single_file' on beta.hydroshare.org: 2.5174052183276676
# Average time 'delete_single_file' on www.hydroshare.org: 15.440319617589315
# Devation for 'delete_single_file' on www.hydroshare.org: 0.1313113007098236
# TtestResult(statistic=6.028489017325856, pvalue=0.0038156852486170593, df=4.0)

# %%
clear_resources()
run_comparisons([delete_single_resource], runs=5)
# Out:
# ********* Start 'delete_single_resource' *********
# Starting run 0 of delete_single_resource on beta.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 31.3772s
# [31.377173900604248]
# Starting run 0 of delete_single_resource on www.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 18.7971s
# [18.79710602760315]
# Starting run 1 of delete_single_resource on beta.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 40.7536s
# [31.377173900604248, 40.75357985496521]
# Starting run 1 of delete_single_resource on www.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 18.4441s
# [18.79710602760315, 18.444146871566772]
# Starting run 2 of delete_single_resource on beta.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 36.8906s
# [31.377173900604248, 40.75357985496521, 36.89060711860657]
# Starting run 2 of delete_single_resource on www.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 18.3291s
# [18.79710602760315, 18.444146871566772, 18.329139947891235]
# Starting run 3 of delete_single_resource on beta.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 28.3761s
# [31.377173900604248, 40.75357985496521, 36.89060711860657, 28.376056909561157]
# Starting run 3 of delete_single_resource on www.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 18.2271s
# [18.79710602760315, 18.444146871566772, 18.329139947891235, 18.22712278366089]
# Starting run 4 of delete_single_resource on beta.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 25.8054s
# [31.377173900604248, 40.75357985496521, 36.89060711860657, 28.376056909561157, 25.805447340011597]
# Starting run 4 of delete_single_resource on www.hydroshare.org...
# Function 'delete_single_resource_inner' executed in 18.1225s
# [18.79710602760315, 18.444146871566772, 18.329139947891235, 18.22712278366089, 18.122507095336914]
# Average time 'delete_single_resource' on beta.hydroshare.org: 32.640573024749756
# Devation for 'delete_single_resource' on beta.hydroshare.org: 5.484248130707255
# Average time 'delete_single_resource' on www.hydroshare.org: 18.38400454521179
# Devation for 'delete_single_resource' on www.hydroshare.org: 0.23249639206269485
# TtestResult(statistic=5.194431169319282, pvalue=0.0008280143524727026, df=8.0)

# %%
run_comparisons([download_all_resources], runs=5)
# Out:
# ********* Start 'download_all_resources' *********
# Starting run 0 of download_all_resources on beta.hydroshare.org...
# Failed GET https://beta.hydroshare.org:443/resource/260c89f293ae43039829bc6044a86991/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:260c89f293ae43039829bc6044a86991"}'
# Failed GET https://beta.hydroshare.org:443/resource/3ab86d344f9f46babfb1397347bc9aa4/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:3ab86d344f9f46babfb1397347bc9aa4"}'
# Failed GET https://beta.hydroshare.org:443/resource/46fc79db9a344665bc4fb48cf6f33561/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:46fc79db9a344665bc4fb48cf6f33561"}'
# Failed GET https://beta.hydroshare.org:443/resource/76cca452f523463292c9a3476756965f/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:76cca452f523463292c9a3476756965f"}'
# Failed GET https://beta.hydroshare.org:443/resource/2f1739e6bea744b3ba875890808acc13/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:2f1739e6bea744b3ba875890808acc13"}'
# Function 'download_all_resources' executed in 6.7628s
# [6.762757062911987]
# Starting run 0 of download_all_resources on www.hydroshare.org...
# Failed GET https://www.hydroshare.org:443/resource/b7e198b846344c5a9f641f7ce91f2e22/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:b7e198b846344c5a9f641f7ce91f2e22"}'
# Failed GET https://www.hydroshare.org:443/resource/aa7582e649734c7392873ae3e8b7253d/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:aa7582e649734c7392873ae3e8b7253d"}'
# Failed GET https://www.hydroshare.org:443/resource/4f1ac67f395a4668bf664b8829387906/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:4f1ac67f395a4668bf664b8829387906"}'
# Failed GET https://www.hydroshare.org:443/resource/086815f8a0a54e7dad1c4491920f3885/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:086815f8a0a54e7dad1c4491920f3885"}'
# Failed GET https://www.hydroshare.org:443/resource/0c14d9c11ab9421b85050c65ccdb8367/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:0c14d9c11ab9421b85050c65ccdb8367"}'
# Function 'download_all_resources' executed in 1.8102s
# [1.8101921081542969]
# Starting run 1 of download_all_resources on beta.hydroshare.org...
# Failed GET https://beta.hydroshare.org:443/resource/260c89f293ae43039829bc6044a86991/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:260c89f293ae43039829bc6044a86991"}'
# Failed GET https://beta.hydroshare.org:443/resource/3ab86d344f9f46babfb1397347bc9aa4/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:3ab86d344f9f46babfb1397347bc9aa4"}'
# Failed GET https://beta.hydroshare.org:443/resource/46fc79db9a344665bc4fb48cf6f33561/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:46fc79db9a344665bc4fb48cf6f33561"}'
# Failed GET https://beta.hydroshare.org:443/resource/76cca452f523463292c9a3476756965f/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:76cca452f523463292c9a3476756965f"}'
# Failed GET https://beta.hydroshare.org:443/resource/2f1739e6bea744b3ba875890808acc13/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:2f1739e6bea744b3ba875890808acc13"}'
# Function 'download_all_resources' executed in 7.7936s
# [6.762757062911987, 7.7936389446258545]
# Starting run 1 of download_all_resources on www.hydroshare.org...
# Failed GET https://www.hydroshare.org:443/resource/b7e198b846344c5a9f641f7ce91f2e22/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:b7e198b846344c5a9f641f7ce91f2e22"}'
# Failed GET https://www.hydroshare.org:443/resource/aa7582e649734c7392873ae3e8b7253d/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:aa7582e649734c7392873ae3e8b7253d"}'
# Failed GET https://www.hydroshare.org:443/resource/4f1ac67f395a4668bf664b8829387906/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:4f1ac67f395a4668bf664b8829387906"}'
# Failed GET https://www.hydroshare.org:443/resource/086815f8a0a54e7dad1c4491920f3885/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:086815f8a0a54e7dad1c4491920f3885"}'
# Failed GET https://www.hydroshare.org:443/resource/0c14d9c11ab9421b85050c65ccdb8367/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:0c14d9c11ab9421b85050c65ccdb8367"}'
# Function 'download_all_resources' executed in 1.7241s
# [1.8101921081542969, 1.7241318225860596]
# Starting run 2 of download_all_resources on beta.hydroshare.org...
# Failed GET https://beta.hydroshare.org:443/resource/260c89f293ae43039829bc6044a86991/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:260c89f293ae43039829bc6044a86991"}'
# Failed GET https://beta.hydroshare.org:443/resource/3ab86d344f9f46babfb1397347bc9aa4/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:3ab86d344f9f46babfb1397347bc9aa4"}'
# Failed GET https://beta.hydroshare.org:443/resource/46fc79db9a344665bc4fb48cf6f33561/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:46fc79db9a344665bc4fb48cf6f33561"}'
# Failed GET https://beta.hydroshare.org:443/resource/76cca452f523463292c9a3476756965f/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:76cca452f523463292c9a3476756965f"}'
# Failed GET https://beta.hydroshare.org:443/resource/2f1739e6bea744b3ba875890808acc13/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:2f1739e6bea744b3ba875890808acc13"}'
# Function 'download_all_resources' executed in 10.1417s
# [6.762757062911987, 7.7936389446258545, 10.141718864440918]
# Starting run 2 of download_all_resources on www.hydroshare.org...
# Failed GET https://www.hydroshare.org:443/resource/b7e198b846344c5a9f641f7ce91f2e22/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:b7e198b846344c5a9f641f7ce91f2e22"}'
# Failed GET https://www.hydroshare.org:443/resource/aa7582e649734c7392873ae3e8b7253d/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:aa7582e649734c7392873ae3e8b7253d"}'
# Failed GET https://www.hydroshare.org:443/resource/4f1ac67f395a4668bf664b8829387906/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:4f1ac67f395a4668bf664b8829387906"}'
# Failed GET https://www.hydroshare.org:443/resource/086815f8a0a54e7dad1c4491920f3885/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:086815f8a0a54e7dad1c4491920f3885"}'
# Failed GET https://www.hydroshare.org:443/resource/0c14d9c11ab9421b85050c65ccdb8367/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:0c14d9c11ab9421b85050c65ccdb8367"}'
# Function 'download_all_resources' executed in 2.0439s
# [1.8101921081542969, 1.7241318225860596, 2.043907880783081]
# Starting run 3 of download_all_resources on beta.hydroshare.org...
# Failed GET https://beta.hydroshare.org:443/resource/260c89f293ae43039829bc6044a86991/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:260c89f293ae43039829bc6044a86991"}'
# Failed GET https://beta.hydroshare.org:443/resource/3ab86d344f9f46babfb1397347bc9aa4/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:3ab86d344f9f46babfb1397347bc9aa4"}'
# Failed GET https://beta.hydroshare.org:443/resource/46fc79db9a344665bc4fb48cf6f33561/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:46fc79db9a344665bc4fb48cf6f33561"}'
# Failed GET https://beta.hydroshare.org:443/resource/76cca452f523463292c9a3476756965f/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:76cca452f523463292c9a3476756965f"}'
# Failed GET https://beta.hydroshare.org:443/resource/2f1739e6bea744b3ba875890808acc13/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:2f1739e6bea744b3ba875890808acc13"}'
# Function 'download_all_resources' executed in 4.7103s
# [6.762757062911987, 7.7936389446258545, 10.141718864440918, 4.71028995513916]
# Starting run 3 of download_all_resources on www.hydroshare.org...
# Failed GET https://www.hydroshare.org:443/resource/b7e198b846344c5a9f641f7ce91f2e22/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:b7e198b846344c5a9f641f7ce91f2e22"}'
# Failed GET https://www.hydroshare.org:443/resource/aa7582e649734c7392873ae3e8b7253d/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:aa7582e649734c7392873ae3e8b7253d"}'
# Failed GET https://www.hydroshare.org:443/resource/4f1ac67f395a4668bf664b8829387906/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:4f1ac67f395a4668bf664b8829387906"}'
# Failed GET https://www.hydroshare.org:443/resource/086815f8a0a54e7dad1c4491920f3885/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:086815f8a0a54e7dad1c4491920f3885"}'
# Failed GET https://www.hydroshare.org:443/resource/0c14d9c11ab9421b85050c65ccdb8367/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:0c14d9c11ab9421b85050c65ccdb8367"}'
# Function 'download_all_resources' executed in 1.8447s
# [1.8101921081542969, 1.7241318225860596, 2.043907880783081, 1.844660997390747]
# Starting run 4 of download_all_resources on beta.hydroshare.org...
# Failed GET https://beta.hydroshare.org:443/resource/260c89f293ae43039829bc6044a86991/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:260c89f293ae43039829bc6044a86991"}'
# Failed GET https://beta.hydroshare.org:443/resource/3ab86d344f9f46babfb1397347bc9aa4/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:3ab86d344f9f46babfb1397347bc9aa4"}'
# Failed GET https://beta.hydroshare.org:443/resource/46fc79db9a344665bc4fb48cf6f33561/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:46fc79db9a344665bc4fb48cf6f33561"}'
# Failed GET https://beta.hydroshare.org:443/resource/76cca452f523463292c9a3476756965f/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:76cca452f523463292c9a3476756965f"}'
# Failed GET https://beta.hydroshare.org:443/resource/2f1739e6bea744b3ba875890808acc13/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:2f1739e6bea744b3ba875890808acc13"}'
# Function 'download_all_resources' executed in 10.5111s
# [6.762757062911987, 7.7936389446258545, 10.141718864440918, 4.71028995513916, 10.511052131652832]
# Starting run 4 of download_all_resources on www.hydroshare.org...
# Failed GET https://www.hydroshare.org:443/resource/b7e198b846344c5a9f641f7ce91f2e22/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:b7e198b846344c5a9f641f7ce91f2e22"}'
# Failed GET https://www.hydroshare.org:443/resource/aa7582e649734c7392873ae3e8b7253d/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:aa7582e649734c7392873ae3e8b7253d"}'
# Failed GET https://www.hydroshare.org:443/resource/4f1ac67f395a4668bf664b8829387906/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:4f1ac67f395a4668bf664b8829387906"}'
# Failed GET https://www.hydroshare.org:443/resource/086815f8a0a54e7dad1c4491920f3885/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:086815f8a0a54e7dad1c4491920f3885"}'
# Failed GET https://www.hydroshare.org:443/resource/0c14d9c11ab9421b85050c65ccdb8367/data/resourcemap.xml/, status_code 404, message b'{"detail":"No resource was found for resource id:0c14d9c11ab9421b85050c65ccdb8367"}'
# Function 'download_all_resources' executed in 1.7762s
# [1.8101921081542969, 1.7241318225860596, 2.043907880783081, 1.844660997390747, 1.7762486934661865]
# Average time 'download_all_resources' on beta.hydroshare.org: 7.983891391754151
# Devation for 'download_all_resources' on beta.hydroshare.org: 2.1580821215000063
# Average time 'download_all_resources' on www.hydroshare.org: 1.8398283004760743
# Devation for 'download_all_resources' on www.hydroshare.org: 0.10952458662489709
# TtestResult(statistic=5.686684297844425, pvalue=0.0004614152827108025, df=8.0)

# %%
# TODO: these ones still seem not to work...
clear_resources()
run_comparisons([upload_and_movefile, download_single_file ], runs=2)
# Out:
# ********* Start 'upload_and_movefile' *********
# Starting run 0 of upload_and_movefile on beta.hydroshare.org...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 # TODO: these ones still seem not to work...
#       2 clear_resources()
# ----> 3 run_comparisons([upload_and_movefile, download_single_file ], runs=2)
#
# Cell In[58], line 131, in run_comparisons(functions_to_run, runs)
#     129         client = clients[target]
#     130         print(f"Starting run {i} of {funct.__name__} on {target}...")
# --> 131         funct(hs=client, target=target)
#     132         print(diffs[target])
#     133 for target in targets:
#
# Cell In[58], line 99, in upload_and_movefile(hs, target)
#      97     file = res.file(path=f"New_Folder/{filename}]")
#      98     res.file_rename(file, filename)
# ---> 99 upload_and_movefile_inner(hs=res, target=target)
#
# Cell In[58], line 10, in timer_func.<locals>.wrap_func(*args, **kwargs)
#       7 @wraps(func)
#       8 def wrap_func(*args, **kwargs):
#       9     t1 = time()
# ---> 10     result = func(*args, **kwargs)
#      11     t2 = time()
#      12     target = kwargs['target']
#
# Cell In[58], line 98, in upload_and_movefile.<locals>.upload_and_movefile_inner(hs, target)
#      96 res.file_upload(filename, destination_path='New_Folder')
#      97 file = res.file(path=f"New_Folder/{filename}]")
# ---> 98 res.file_rename(file, filename)
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:114, in refresh.<locals>.wrapper(*args, **kwargs)
#     112 self = args[0]
#     113 do_refresh = kwargs.pop("refresh", True)
# --> 114 result = f(*args, **kwargs)
#     115 if do_refresh:
#     116     self.refresh()
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:1028, in Resource.file_rename(self, path, new_path)
#    1021 """
#    1022 Rename a file on HydroShare
#    1023 :param path: The path to the file
#    1024 :param new_path: the renamed path to the file
#    1025 :return: None
#    1026 """
#    1027 rename_path = urljoin(self._hsapi_path, "functions", "move-or-rename")
# -> 1028 self._hs_session.post(rename_path, status_code=200, data={"source_path": path, "target_path": new_path})
#
# File ~/repos/hydroshare/venv/lib/python3.11/site-packages/hsclient/hydroshare.py:1273, in HydroShareSession.post(self, path, status_code, data, params, **kwargs)
#    1271 response = self._session.post(url, params=params, data=data, **kwargs)
#    1272 if response.status_code != status_code:
# -> 1273     raise Exception(
#    1274         "Failed POST {}, status_code {}, message {}".format(url, response.status_code, response.content)
#    1275     )
#    1276 return response
#
# Exception: Failed POST https://beta.hydroshare.org:443/hsapi/resource/d62d2796cb6c432088ce3c810763e9cb/functions/move-or-rename/, status_code 400, message b'{"error": "[\'A value for path is missing\']"}'
